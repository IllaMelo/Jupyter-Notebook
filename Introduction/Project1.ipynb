# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Crating a dataframe

# %%
# Array with numpy
data = np.array([[1,4],[2,6],[3,6]])

# %%
# Dataframe with pandas
df = pd.DataFrame(data, index=['row1','row2','row3'],columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     6
# row3     3     6

# %% [markdown]
# ## Creating a dataframe from a dictionary

# %%
states = ['California', 'Texas', 'Florida']
population = [39613493,29730311,21944577]

# %%
dictStates = {'States':states,'Population':population}

# %%
df_population = pd.DataFrame(dictStates)

# %%
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577

# %% [markdown]
# ## Creating a dataframe from  a csv file

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# ## Attributes

# %%
#Access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
#Index atribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#Column
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#Type of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ## Methods

# %%
#Info
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Describing 
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Functions

# %%
#Length
len(df_exams)
# Out:
# 1000

# %%
# Highest index of the dataframe
max(df_exams.index)
# Out:
# 999

# %% [markdown]
# ## Selecting one column

# %%
# Select a column with []
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# ## Add a new Column

# %% [markdown]
# ##### Assign()

# %%
# Create random number for our new score columns
score_one = np.random.randint(1,100, size=1000)

# %%
# Create a series using random number
serie_one = pd.Series(score_one, index=np.arange(0,1000))

# %%
#Add multiple columns
df_exams.assign(score_one=serie_one)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      score_one
# 0           58
# 1           33
# 2           73
# 3           66
# 4           83
# ..         ...
# 995         47
# 996         92
# 997         68
# 998         86
# 999         26
#
# [1000 rows x 9 columns]

# %% [markdown]
# #### Insert()

# %%
#Insert a new column at a specific position
df_exams.insert(1, "test", serie_one)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    58        group B           bachelor's degree      standard
# 1    female    33        group C                some college      standard
# 2    female    73        group B             master's degree      standard
# 3      male    66        group A          associate's degree  free/reduced
# 4      male    83        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    47        group E             master's degree      standard
# 996    male    92        group C                 high school  free/reduced
# 997  female    68        group C                 high school  free/reduced
# 998  female    86        group D                some college      standard
# 999  female    26        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Math Operations

# %% [markdown]
# ### Columns

# %%
# Select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# 66089

# %%
# Count, mean, std, max and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# Describe()
df_exams.describe()
# Out:
#              test  math score  reading score  writing score
# count  1000.00000  1000.00000    1000.000000    1000.000000
# mean     51.28900    66.08900      69.169000      68.054000
# std      28.16851    15.16308      14.600192      15.195657
# min       1.00000     0.00000      17.000000      10.000000
# 25%      27.00000    57.00000      59.000000      57.750000
# 50%      52.00000    66.00000      70.000000      69.000000
# 75%      76.00000    77.00000      79.000000      79.000000
# max      99.00000   100.00000     100.000000     100.000000

# %% [markdown]
# ### Rows

# %%
# Sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %% [markdown]
# # Value counts

# %%
#len function
len(df_exams['gender'])
#count method
df_exams['gender'].count()
# Out:
# 1000

# %%
# Gender elements by category
df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# Relative frequency
df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %% [markdown]
# # Sort a dataframe

# %%
# sort by one column
df_exams.sort_values('math score', ascending=False) #True as defalut
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 962  female    73        group E          associate's degree      standard
# 625    male    45        group D                some college      standard
# 458  female    43        group E           bachelor's degree      standard
# 623    male    49        group A                some college      standard
# 451  female     2        group E                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    60        group C                some college  free/reduced
# 787  female    52        group B                some college      standard
# 17   female    73        group B            some high school  free/reduced
# 980  female    56        group B                 high school  free/reduced
# 59   female    85        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Create Index

# %%
import random

# %%
new_index = np.arange(0, 1000)

# %%
random.shuffle(new_index)

# %%
df_exams['new_index'] = new_index

# %%
df_exams.set_index('new_index')
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 735        female    58        group B           bachelor's degree
# 929        female    33        group C                some college
# 887        female    73        group B             master's degree
# 670          male    66        group A          associate's degree
# 11           male    83        group C                some college
# ...           ...   ...            ...                         ...
# 138        female    47        group E             master's degree
# 32           male    92        group C                 high school
# 17         female    68        group C                 high school
# 565        female    86        group D                some college
# 462        female    26        group D                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 735            standard                    none          72             72
# 929            standard               completed          69             90
# 887            standard                    none          90             95
# 670        free/reduced                    none          47             57
# 11             standard                    none          76             78
# ...                 ...                     ...         ...            ...
# 138            standard               completed          88             99
# 32         free/reduced                    none          62             55
# 17         free/reduced               completed          59             71
# 565            standard               completed          68             78
# 462        free/reduced                    none          77             86
#
#            writing score
# new_index
# 735                   74
# 929                   88
# 887                   93
# 670                   44
# 11                    75
# ...                  ...
# 138                   95
# 32                    55
# 17                    65
# 565                   77
# 462                   86
#
# [1000 rows x 9 columns]

# %%
# Rename columns
df_exams.rename(columns = {
   'maths score':'MS',
    'reading score': 'RS',
    'writing score': 'WS'
}, inplace=True)

# %%
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 735        female    58        group B           bachelor's degree
# 929        female    33        group C                some college
# 887        female    73        group B             master's degree
# 670          male    66        group A          associate's degree
# 11           male    83        group C                some college
# ...           ...   ...            ...                         ...
# 138        female    47        group E             master's degree
# 32           male    92        group C                 high school
# 17         female    68        group C                 high school
# 565        female    86        group D                some college
# 462        female    26        group D                some college
#
#                   lunch test preparation course  math score  RS  WS  new_index
# new_index
# 735            standard                    none          72  72  74        735
# 929            standard               completed          69  90  88        929
# 887            standard                    none          90  95  93        887
# 670        free/reduced                    none          47  57  44        670
# 11             standard                    none          76  78  75         11
# ...                 ...                     ...         ...  ..  ..        ...
# 138            standard               completed          88  99  95        138
# 32         free/reduced                    none          62  55  55         32
# 17         free/reduced               completed          59  71  65         17
# 565            standard               completed          68  78  77        565
# 462        free/reduced                    none          77  86  86        462
#
# [1000 rows x 10 columns]
